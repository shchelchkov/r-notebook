# %%
import http.client

conn = http.client.HTTPConnection("r-function-orderbook:8203")
payload = ""
conn.request("GET", "/api/functions/values/obi_state/BTCUSDT", payload)

res = conn.getresponse()
json_data = res.read()

print(json_data.decode("utf-8"))
# Out:
# {"data":[{"imbalanceEma":-0.32611876902971676,"z_score_x_2_x":0.03634726076498955,"z_score_var_2_mu":-0.06031671660039878,"symbol":"BTCUSDT","imbalanceEma2":-0.32611876902971676,"z_score_var_2_x":0.03634726076498955,"lr_x":0.05687506000555637,"instant":1789052658345716959,"z_score2_mu":-0.06031671660039878,"z_score9_x":0.00036337501935036266,"z_score_var_9_x":0.0010431103822905847,"dbid_mu":0.11413640979671331,"z_score_var_9_mu":-0.9710819620019945,"dask_mu":0.20160757005650887,"z_score_x_2_mu":-0.06031671660039878,"z_score2_x":0.03634726076498955,"z_score_x_9_x":0.0010431103822905847,"dt_slow":64.52933033886895,"regime_n":429137.0,"bd_x":0.33401836400699153,"regime_share":8.756854652602388e-15,"z_score9_mu":-0.30716448006403274,"dask_x":0.12841771225444037,"imbalanceEma9":-0.9895188828286561,"lq_x":0.005701932498089105,"bd_mu":-0.0874711602597956,"z_score_x_9_mu":-0.9710819620019945,"frag_slow":55.82739856303763,"depth_x":1.3970881192709077,"regime_cooldown_until":0,"timestamp":0,"depth_mu":0.9950204689531886,"lr_mu":-0.020816174104570175,"lq_mu":0.0022219511251252073,"frag_fast":65.76518639376151,"dt_fast":68.5514541866941,"dbid_x":0.1865151418028428}]}

# %%
import json
import pandas as pd

data = json.loads(json_data)

df = pd.DataFrame(data["data"])

# %%
df
# Out:
#    imbalanceEma  z_score_x_2_x  z_score_var_2_mu   symbol  imbalanceEma2  \
# 0     -0.326119       0.036347         -0.060317  BTCUSDT      -0.326119
#
#    z_score_var_2_x      lr_x              instant  z_score2_mu  z_score9_x  \
# 0         0.036347  0.056875  1789052658345716959    -0.060317    0.000363
#
#    ...  frag_slow   depth_x  regime_cooldown_until  timestamp  depth_mu  \
# 0  ...  55.827399  1.397088                      0          0   0.99502
#
#       lr_mu     lq_mu  frag_fast    dt_fast    dbid_x
# 0 -0.020816  0.002222  65.765186  68.551454  0.186515
#
# [1 rows x 37 columns]

# %%
import requests

url = "http://r-function-orderbook:8203/api/functions/values/obi_state"

response = requests.get(url)

print(response.json())
# Out:
# {'data': [{'key': 'obi_state.TAOUSDT', 'values': [{'dt_slow': 55.059822481468046, 'dbid_mu': 3.581686553510141, 'imbalanceEma': 0.39608470096126724, 'z_score_var_9_mu': 0.44003576564599245, 'frag_slow': 0.1037758966053264, 'dbid_x': 7.069362062908551, 'z_score_x_2_mu': 0.4065822019137831, 'dask_mu': 0.1490598774513477, 'lq_mu': 0.005187428090507629, 'lq_x': 0.005463386286878562, 'z_score_var_2_mu': 0.4065822019137831, 'frag_fast': 0.06711617211558984, 'imbalanceEma2': 0.39608470096126724, 'z_score_var_9_x': 0.0023751335495782178, 'lr_mu': -0.13799857008674937, 'imbalanceEma9': 0.39543440023505705, 'bd_mu': 3.4326266760587933, 'z_score2_mu': 0.4065822019137831, 'z_score_x_2_x': 0.010952537871980847, 'z_score_x_9_mu': 0.44003576564599245, 'z_score2_x': 0.010952537871980847, 'regime_n': 431049.0, 'dask_x': 2.18740361053552, 'regime_cooldown_until': 1789051937276612352, 'z_score9_mu': 0.3961032809820161, 'dt_fast': 51.95719904434711, 'z_score
# %%
data = response.json()
df = pd.DataFrame(data["data"])

# %%
df
# Out:
#                                              key  \
# 0                              obi_state.TAOUSDT
# 1                              obi_state.ZECUSDT
# 2                            obi_state.ASTERUSDT
# 3       obi_state.__wd_cooldown_bybit_orderbook3
# 4                              obi_state.XMRUSDT
# 5                         obi_state.1000PEPEUSDT
# 6                             obi_state.AVAXUSDT
# 7                              obi_state.LDOUSDT
# 8                             obi_state.HYPEUSDT
# 9                              obi_state.SOLUSDT
# 10                        obi_state.1000BONKUSDT
# 11                            obi_state.WLFIUSDT
# 12                             obi_state.WIFUSDT
# 13                             obi_state.XLMUSDT
# 14                        obi_state.SHIB1000USDT
# 15                            obi_state.COMPUSDT
# 16      obi_state.__wd_cooldown_bybit_orderbook2
# 17                            obi_state.DOGEUSDT
# 18  obi_state.__wd_cooldown_bybit_orderbook_nvda
# 19                             obi_state.UNIUSDT
# 20                             obi_state.WLDUSDT
# 21                             obi_state.LITUSDT
# 22                            obi_state.DASHUSDT
# 23                             obi_state.SUIUSDT
# 24      obi_state.__wd_cooldown_bybit_orderbook0
# 25                             obi_state.ETHUSDT
# 26                           obi_state.CYBERUSDT
# 27                             obi_state.DOTUSDT
# 28                             obi_state.BTCUSDT
# 29                             obi_state.STGUSDT
# 30                             obi_state.MYXUSDT
# 31                             obi_state.BCHUSDT
# 32                             obi_state.TRXUSDT
# 33                             obi_state.FILUSDT
# 34                            obi_state.HBARUSDT
# 35                             obi_state.ARBUSDT
# 36                              obi_state.OPUSDT
# 37                             obi_state.BNBUSDT
# 38                             obi_state.MONUSDT
# 39                             obi_state.XRPUSDT
# 40     obi_state.__wd_cooldown_bybit_orderbook_x
# 41                        obi_state.1000RATSUSDT
# 42                             obi_state.XAUUSDT
# 43      obi_state.__wd_cooldown_bybit_orderbook1
# 44                         obi_state.PUMPFUNUSDT
# 45                             obi_state.LTCUSDT
# 46                            obi_state.NVDAUSDT
# 47                             obi_state.JTOUSDT
# 48                             obi_state.APTUSDT
# 49                             obi_state.XAGUSDT
# 50                             obi_state.INJUSDT
# 51                            obi_state.LINKUSDT
# 52                             obi_state.ENAUSDT
# 53                              obi_state.CLUSDT
# 54   obi_state.__wd_cooldown_bybit_orderbook1000
# 55                             obi_state.ADAUSDT
#
#                                                values
# 0   [{'dt_slow': 55.059822481468046, 'dbid_mu': 3....
# 1   [{'symbol': 'ZECUSDT', 'dbid_x': 0.62608245335...
# 2   [{'frag_fast': 0.0006543495770881217, 'z_score...
# 3                  [{'instant': 1789052683778679435}]
# 4   [{'imbalanceEma2': -0.7233208013645362, 'insta...
# 5   [{'depth_mu': 22576536.826275907, 'z_score9_mu...
# 6   [{'z_score_var_9_x': 4.217825758954021e-09, 'd...
# 7   [{'lq_mu': -0.0014793078055080058, 'imbalanceE...
# 8   [{'z_score9_mu': -0.3521422090795259, 'frag_sl...
# 9   [{'lq_x': 0.005136049861428383, 'z_score2_mu':...
# 10  [{'imbalanceEma': 0.1226132532573494, 'lr_x': ...
# 11  [{'dask_mu': 13731.869052091188, 'frag_slow': ...
# 12  [{'z_score9_x': 0.00018597344625535106, 'z_sco...
# 13  [{'bd_x': 145656475753.59442, 'lq_mu': -0.0007...
# 14  [{'lr_x': 0.6551454665928556, 'z_score_var_2_x...
# 15  [{'z_score9_mu': -0.10858086126642683, 'frag_s...
# 16                 [{'instant': 1789052143777969231}]
# 17  [{'symbol': 'DOGEUSDT', 'regime_cooldown_until...
# 18                 [{'instant': 1789042363777874073}]
# 19  [{'bd_x': 1470624.6121011355, 'imbalanceEma': ...
# 20  [{'regime_n': 205935.0, 'z_score_var_9_mu': 0....
# 21  [{'dask_mu': 409.65844002510767, 'z_score_var_...
# 22  [{'z_score_var_9_x': 0.02887528415930756, 'dbi...
# 23  [{'imbalanceEma': 0.3373680636402701, 'z_score...
# 24                 [{'instant': 1789042363777874073}]
# 25  [{'regime_cooldown_until': 0, 'z_score9_x': 1....
# 26  [{'lq_x': 0.03211738104983445, 'depth_x': 7316...
# 27  [{'z_score_x_2_x': 0.024918901926988837, 'dask...
# 28  [{'imbalanceEma': 0.03747719677726424, 'frag_s...
# 29  [{'timestamp': 0, 'z_score9_mu': -0.2630752152...
# 30  [{'lr_x': 0.11506811969781344, 'imbalanceEma':...
# 31  [{'z_score_x_2_x': 0.021686869498922155, 'lr_x...
# 32  [{'symbol': 'TRXUSDT', 'z_score_x_9_x': 0.0040...
# 33  [{'lq_mu': 0.005220889852680102, 'regime_coold...
# 34  [{'instant': 1789052694812897065, 'z_score2_mu...
# 35  [{'depth_x': 3190641479.1431556, 'imbalanceEma...
# 36  [{'z_score9_mu': -0.5037828477843946, 'dbid_mu...
# 37  [{'dbid_x': 2834.511194327468, 'lr_x': 0.31830...
# 38  [{'dask_x': 394522261412.1393, 'imbalanceEma2'...
# 39  [{'z_score_var_9_mu': -0.9463556632009016, 'z_...
# 40                 [{'instant': 1789042363777874073}]
# 41  [{'imbalanceEma9': 0.99999999982, 'lr_x': 0.05...
# 42  [{'z_score2_x': 0.020866986089102313, 'timesta...
# 43                 [{'instant': 1789042363777874073}]
# 44  [{'z_score_var_9_mu': -0.8075320671126609, 'z_...
# 45  [{'frag_fast': 0.0503999064597063, 'z_score9_x...
# 46  [{'regime_cooldown_until': 0, 'regime_share': ...
# 47  [{'regime_cooldown_until': 0, 'lr_mu': -0.1587...
# 48  [{'z_score_var_9_x': 0.0004319147369108872, 'z...
# 49  [{'bd_x': 422813.1439032562, 'dbid_mu': 278.55...
# 50  [{'symbol': 'INJUSDT', 'lr_x': 0.0567699494431...
# 51  [{'imbalanceEma9': -0.8019906253215193, 'imbal...
# 52  [{'dt_fast': 58.148588233849765, 'z_score9_mu'...
# 53  [{'dt_slow': 58.3880703744373, 'z_score_x_9_mu...
# 54                 [{'instant': 1789048063778286604}]
# 55  [{'lr_mu': -0.4338860726538833, 'lq_mu': 0.000...

# %%
def values(setting="obi_state",
           code="BTCUSDT"):
    base_url = f"http://r-function-orderbook:8203/api/functions/values/{setting}/{code}"
    response = requests.get(base_url)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        return None

# %%
data=values("obi_state", "BTCUSDT")
df = pd.DataFrame(data["data"])

# %%
df
# Out:
#    depth_mu      lr_x  regime_cooldown_until  timestamp   dask_mu    dt_fast  \
# 0  3.862677  0.056596                      0          0  0.097377  62.982681
#
#    z_score_x_9_mu  imbalanceEma9   depth_x     lq_mu  ...  z_score9_x  \
# 0        0.470106       0.411532  15.24482  0.002175  ...    0.000043
#
#    z_score_var_9_mu   symbol  z_score_var_2_x     lr_mu     bd_mu  frag_slow  \
# 0          0.470106  BTCUSDT         0.036012 -0.017902 -0.009815   60.47781
#
#                instant  frag_fast      bd_x
# 0  1789052704765682911  69.063838  0.205108
#
# [1 rows x 37 columns]
